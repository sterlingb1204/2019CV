# %%
http://web.mta.info/developers/data/nyct/turnstile/turnstile_190316.txt
# Out:
#   File "<ipython-input-1-6f914b190676>", line 1
#     http://web.mta.info/developers/data/nyct/turnstile/turnstile_190316.txt
#           ^
# SyntaxError: invalid syntax

# %%
import os
import requests
import string

from ipywidgets import interact

# %%
def wget(url):

    response = requests.get(url)
    path     = os.path.basename(url)
   
    with open(path,'wb') as f: #automatically closes the file
        f.write(response.content)
        
    ''' Download file from specified url and store in file '''
    # TODO: store contents of response.content to file located at path

# %%
wget("http://web.mta.info/developers/data/nyct/turnstile/turnstile_190316.txt")

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# Set the URL you want to webscrape from
url = "https://www.britannica.com/story/history-of-technology-timeline"

# Connect to the URL
response = requests.get(url)

# Parse HTML and save to BeautifulSoup object¶
soup = BeautifulSoup(response.text, "html.parser")

# To download the whole data set, let's do a for loop through all br tags
for i in range(len(soup.findAll('br'))): #'br' tags are for links
    one_a_tag = soup.findAll('br')[i]
    download_url = 'https://www.britannica.com/story/history-of-technology-timeline'+ link
    urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-710e929c6416> in <module>()
#      16 for i in range(len(soup.findAll('br'))): #'br' tags are for links
#      17     one_a_tag = soup.findAll('br')[i]
# ---> 18     download_url = 'https://www.britannica.com/story/history-of-technology-timeline'+ link
#      19     urllib.request.urlretrieve(download_url,'./'+link[link.find('/turnstile_')+1:])
#
# NameError: name 'link' is not defined

# %%
ul class = "bullet"
# Out:
#   File "<ipython-input-62-642a4e91c4aa>", line 1
#     ul class = "bullet"
#            ^
# SyntaxError: invalid syntax

# %%
import bs4 as bs
import urllib.request

sauce = urllib.request.urlopen("https://www.britannica.com/story/history-of-technology-timeline").read()
soup = bs.BeautifulSoup(sauce, "lxml") #turns parsed info into soup object in order to interact with data

# %%
for line in soup.find_all('li'):
    sentences = line.text.split(". ") #stores as list
    print(sentences)
# Out:
# ['Demystified']
# ['Quizzes']
# ['Galleries']
# ['Lists']
# ['On This Day']
# ['Biographies']
# ['\n100 Women\n']
# ['United States presidential election of 1860']
# ['Amelia Earhart']
# ['List of countries in Latin America']
# ['Abraham Lincoln']
# ['Benito Mussolini']
# ['3.3 million years ago: The first toolsThe history of technology begins even before the beginning of our own species', 'Sharp flakes of stone used as knives and larger unshaped stones used as hammers and anvils have been uncovered at Lake Turkana in Kenya', 'The tools were made 3.3 million years ago and thus were likely used by an ancestor such as Australopithecus.']
# ['1 million years ago: FireWhen humanity first used fire is still not definitively known, but, like the first tools, it was probably invented by an ancestor of Homo sapiens', 'Evidence of burnt material can be found in caves used by Homo erectus beginning about 1 million (and maybe even 1.5 million) years ago.']
# ...

# %%
print(soup.title.string) # displays title as string returns navigable string
print(soup.title.text) # does same thing as above returns unicode use when there are child tags

#print(soup.find_all("li"))

#print(soup.get_text())

#for url in soup.find_all("a"):
    #print(url.get("href"))
phrases = {}
for line in soup.find_all('li'):
    sentences = line.text.split(". ") #stores as list
    for enum,word in enumerate(sentences): # loads individual lines into dictionary
        phrases[word] = enum

for key, values in enumerate(phrases):
    print(phrases)
# Out:
# History of Technology Timeline | Britannica.com
# History of Technology Timeline | Britannica.com
# ...
